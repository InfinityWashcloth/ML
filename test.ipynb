# %%
# %matplotlib notebook

import glob
import os
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram

# %%
def load_sound_files(file_paths):
    raw_sounds = []
    for fp in file_paths:
        X, sr = librosa.load(fp)
        raw_sounds.append(X)
    return raw_sounds

# %%
def plot_waves(sound_names, raw_sounds):
    i = 1
    fig = plt.figure()
    for n,f in zip(sound_names,raw_sounds):
        plt.subplot(10,1,i)
        librosa.display.waveplot(np.array(f),sr=22050)
        plt.title(n.title())
        i += 1
    plt.suptitle("Figure 1: Waveplot",x=0.5, y=0.915,fontsize=18)
    plt.show()

# %%
def plot_specgram(sound_names, raw_sounds):
    i = 1
    fig = plt.figure()
    for n, f in zip(sound_names, raw_sounds):
        plt.subplot(10, 1, i)
        specgram(np.array(f), Fs=22050)
        plt.title(n.title())
        i += 1
    plt.suptitle("Figure 2: Spectrogram", x=0.5, y=0.915, fontsize=18)
    plt.show()

# %%
def plot_log_power_specgram(sound_names, raw_sounds):
    i = 1
    fig = plt.figure()
    for n, f in zip(sound_names, raw_sounds):
        plt.subplot(10, 1, i)
        D = librosa.core.amplitude_to_db(np.abs(librosa.stft(f)) ** 2)
        librosa.display.specshow(D, x_axis='time', y_axis='log')
        plt.title(n.title())
        i += 1
    plt.suptitle("Figure 3: Log power spectrogram", x=0.5, y=0.915, fontsize=18)
    plt.show()

# %%
sound_file_paths = ['sounds/car_horn/7061-6-0-0.wav']

# %%
sound_names = ["car horn"]

# %%
raw_sounds = load_sound_files(sound_file_paths)

# %%
def extract_feature(file_name):
    X, sample_rate = librosa.load(file_name)
    stft = np.abs(librosa.stft(X))
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),
    sr=sample_rate).T,axis=0)
    return mfccs,chroma,mel,contrast,tonnetz

# %%
def parse_audio_files(parent_dir,sub_dirs,file_ext="*.wav"):
    features, labels = np.empty((0,193)), np.empty(0)
    for label, sub_dir in enumerate(sub_dirs):
        files = glob.glob(os.path.join(parent_dir, sub_dir, file_ext))
        for i, fn in enumerate(files):
            print("{}, {} left".format(fn, len(files) - i))
            try:
              mfccs, chroma, mel, contrast,tonnetz = extract_feature(fn)
            except Exception as e:
              print("Error encountered while parsing file: ", fn)
              continue
            ext_features = np.hstack([mfccs,chroma,mel,contrast,tonnetz])
            features = np.vstack([features,ext_features])
            labels = np.append(labels, fn.split('/')[2].split('-')[1])
    return np.array(features), np.array(labels, dtype = np.int)

# %%
def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels,n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels] = 1
    return one_hot_encode

# %%
# plot_waves(sound_names, raw_sounds)
# plot_specgram(sound_names, raw_sounds)
# plot_log_power_specgram(sound_names, raw_sounds)

# %%
import tensorflow as tf
from sklearn.metrics import precision_recall_fscore_support

# %%
parent_dir = 'sounds'

sub_dirs = ['car_horn']
features, labels = parse_audio_files(parent_dir, sub_dirs)
# Out:
# sounds/car_horn/135776-2-0-49.wav, 873 left
# sounds/car_horn/46654-6-0-0.wav, 872 left
# sounds/car_horn/57320-0-0-24.wav, 871 left
# sounds/car_horn/134717-0-0-26.wav, 870 left
# sounds/car_horn/174276-7-5-0.wav, 869 left
# sounds/car_horn/180937-7-2-6.wav, 868 left
# sounds/car_horn/17913-4-0-1.wav, 867 left
# sounds/car_horn/103074-7-4-6.wav, 866 left
# sounds/car_horn/176787-5-0-9.wav, 865 left
# sounds/car_horn/193394-3-0-10.wav, 281 left
# sounds/car_horn/159738-8-0-17.wav, 280 left
# sounds/car_horn/78360-4-0-5.wav, 279 left
# sounds/car_horn/176787-5-0-14.wav, 278 left
# sounds/car_horn/177621-0-0-93.wav, 277 left
# sounds/car_horn/176787-5-0-28.wav, 276 left
# sounds/car_horn/196065-2-0-0.wav, 275 left
# sounds/car_horn/124489-9-0-6.wav, 274 left
# sounds/car_horn/193698-2-0-58.wav, 273 left
# sounds/car_horn/57320-0-0-7.wav, 272 left
# sounds/car_horn/193698-2-0-64.wav, 271 left
# sounds/car_horn/99180-9-0-48.wav, 270 left
# sounds/car_horn/7383-3-0-1.wav, 269 left
# sounds/car_horn/176714-2-0-40.wav, 268 left
# sounds/car_horn/147764-4-7-0.wav, 267 left
# sounds/car_horn/180256-3-0-3.wav, 266 left
# sounds/car_horn/24074-1-0-0.wav, 265 left
# sounds/car_horn/177621-0-0-104.wav, 264 left
# sounds/car_horn/24074-1-0-2.wav, 263 left
# sounds/car_horn/135776-2-0-32.wav, 262 left
# sounds/car_horn/180256-3-0-1.wav, 261 left
# sounds/car_horn/57320-0-0-5.wav, 260 left
# sounds/car_horn/176638-1-1-0.wav, 259 left
# sounds/car_horn/177621-0-0-46.wav, 258 left
# sounds/car_horn/46656-6-4-0.wav, 257 left
# sounds/car_horn/147764-4-5-0.wav, 256 left
# sounds/car_horn/177621-0-0-91.wav, 255 left
# sounds/car_horn/164312-3-4-0.wav, 254 left
# sounds/car_horn/176787-5-0-16.wav, 253 left
# sounds/car_horn/78360-4-0-7.wav, 252 left
# sounds/car_horn/159738-8-0-15.wav, 251 left
# sounds/car_horn/50901-0-1-0.wav, 250 left
# sounds/car_horn/73277-9-0-19.wav, 249 left
# sounds/car_horn/118963-3-0-0.wav, 248 left
# sounds/car_horn/114587-3-0-7.wav, 247 left
# sounds/car_horn/165067-2-0-9.wav, 246 left
# sounds/car_horn/46669-4-0-45.wav, 245 left
# sounds/car_horn/102106-3-0-0.wav, 244 left
# sounds/car_horn/78360-4-0-18.wav, 243 left
# sounds/car_horn/161702-9-0-30.wav, 242 left
# sounds/car_horn/103258-5-0-3.wav, 241 left
# sounds/car_horn/180937-7-3-9.wav, 240 left
# sounds/car_horn/103258-5-0-2.wav, 239 left
# sounds/car_horn/180937-7-3-8.wav, 238 left
# sounds/car_horn/78360-4-0-19.wav, 237 left
# sounds/car_horn/21684-9-0-39.wav, 236 left
# sounds/car_horn/65749-3-1-24.wav, 235 left
# sounds/car_horn/105415-2-0-21.wav, 234 left
# sounds/car_horn/77246-6-0-0.wav, 233 left
# sounds/car_horn/73277-9-0-24.wav, 232 left
# sounds/car_horn/50901-0-1-1.wav, 231 left
# sounds/car_horn/108362-2-0-29.wav, 230 left
# sounds/car_horn/78360-4-0-6.wav, 229 left
# sounds/car_horn/159738-8-0-14.wav, 228 left
# sounds/car_horn/176787-5-0-17.wav, 227 left
# sounds/car_horn/177621-0-0-47.wav, 226 left
# sounds/car_horn/57320-0-0-4.wav, 225 left
# sounds/car_horn/180937-7-2-10.wav, 224 left
# sounds/car_horn/180256-3-0-0.wav, 223 left
# sounds/car_horn/24074-1-0-3.wav, 222 left
# sounds/car_horn/97317-2-0-36.wav, 221 left
# sounds/car_horn/135776-2-0-40.wav, 220 left
# sounds/car_horn/97317-2-0-22.wav, 219 left
# sounds/car_horn/138031-2-0-13.wav, 218 left
# sounds/car_horn/176714-2-0-18.wav, 217 left
# sounds/car_horn/57320-0-0-39.wav, 216 left
# sounds/car_horn/102842-3-1-0.wav, 215 left
# sounds/car_horn/72261-3-0-17.wav, 214 left
# sounds/car_horn/134717-0-0-13.wav, 213 left
# sounds/car_horn/146186-5-0-4.wav, 212 left
# sounds/car_horn/57320-0-0-11.wav, 211 left
# sounds/car_horn/46656-6-3-0.wav, 210 left
# sounds/car_horn/157867-8-0-19.wav, 209 left
# sounds/car_horn/164312-3-3-0.wav, 208 left
# sounds/car_horn/160009-2-0-47.wav, 207 left
# sounds/car_horn/176787-5-0-0.wav, 206 left
# sounds/car_horn/157867-8-0-25.wav, 205 left
# sounds/car_horn/55020-4-0-3.wav, 204 left
# sounds/car_horn/147764-4-2-0.wav, 203 left
# sounds/car_horn/139951-9-0-13.wav, 202 left
# sounds/car_horn/57584-4-0-1.wav, 201 left
# sounds/car_horn/143651-2-0-20.wav, 200 left
# sounds/car_horn/180937-7-3-23.wav, 199 left
# sounds/car_horn/71087-4-0-0.wav, 198 left
# sounds/car_horn/174290-6-3-0.wav, 197 left
# sounds/car_horn/46918-5-0-1.wav, 196 left
# sounds/car_horn/118279-8-0-1.wav, 195 left
# sounds/car_horn/46669-4-0-37.wav, 194 left
# sounds/car_horn/59277-0-0-3.wav, 193 left
# sounds/car_horn/180937-7-4-9.wav, 192 left
# sounds/car_horn/159738-8-0-8.wav, 191 left
# sounds/car_horn/118279-8-0-14.wav, 190 left
# sounds/car_horn/159738-8-0-9.wav, 189 left
# sounds/car_horn/180937-7-4-8.wav, 188 left
# sounds/car_horn/59277-0-0-2.wav, 187 left
# sounds/car_horn/46669-4-0-36.wav, 186 left
# sounds/car_horn/194732-9-0-171.wav, 185 left
# sounds/car_horn/161702-9-0-8.wav, 184 left
# sounds/car_horn/118279-8-0-0.wav, 183 left
# sounds/car_horn/46918-5-0-0.wav, 182 left
# sounds/car_horn/98223-7-9-0.wav, 181 left
# sounds/car_horn/180937-7-3-22.wav, 180 left
# sounds/car_horn/57584-4-0-0.wav, 179 left
# sounds/car_horn/166268-3-2-0.wav, 178 left
# sounds/car_horn/89948-5-0-0.wav, 177 left
# sounds/car_horn/55020-4-0-2.wav, 176 left
# sounds/car_horn/157867-8-0-24.wav, 175 left
# sounds/car_horn/176787-5-0-1.wav, 174 left
# sounds/car_horn/157867-8-0-18.wav, 173 left
# sounds/car_horn/87275-1-1-0.wav, 172 left
# Error encountered while parsing file:  sounds/car_horn/87275-1-1-0.wav
# sounds/car_horn/197318-6-9-0.wav, 171 left
# /Users/innokentijmin/PycharmProjects/junction_outotec_ML/venv/lib/python3.6/site-packages/librosa/util/utils.py:1467: RuntimeWarning: invalid value encountered in less
#   if np.any(X < 0) or np.any(X_ref < 0):
# /Users/innokentijmin/PycharmProjects/junction_outotec_ML/venv/lib/python3.6/site-packages/librosa/util/utils.py:1479: RuntimeWarning: invalid value encountered in maximum
#   Z = np.maximum(X, X_ref).astype(dtype)
# /Users/innokentijmin/PycharmProjects/junction_outotec_ML/venv/lib/python3.6/site-packages/librosa/util/utils.py:1480: RuntimeWarning: invalid value encountered in less
#   bad_idx = (Z < np.finfo(dtype).tiny)
# sounds/car_horn/177621-0-0-35.wav, 170 left
# sounds/car_horn/155202-9-0-135.wav, 169 left
# sounds/car_horn/57320-0-0-10.wav, 168 left
# sounds/car_horn/146186-5-0-5.wav, 167 left
# sounds/car_horn/134717-0-0-12.wav, 166 left
# sounds/car_horn/122690-6-0-0.wav, 165 left
# sounds/car_horn/57320-0-0-38.wav, 164 left
# sounds/car_horn/97317-2-0-23.wav, 163 left
# sounds/car_horn/87275-1-3-0.wav, 162 left
# sounds/car_horn/176714-2-0-33.wav, 161 left
# sounds/car_horn/146186-5-0-7.wav, 160 left
# sounds/car_horn/176787-5-0-3.wav, 159 left
# sounds/car_horn/160009-2-0-50.wav, 158 left
# sounds/car_horn/55020-4-0-0.wav, 157 left
# sounds/car_horn/157867-8-0-26.wav, 156 left
# sounds/car_horn/196400-6-0-0.wav, 155 left
# sounds/car_horn/125791-3-0-13.wav, 154 left
# sounds/car_horn/69304-9-0-7.wav, 153 left
# sounds/car_horn/57584-4-0-2.wav, 152 left
# sounds/car_horn/137156-9-0-79.wav, 151 left
# sounds/car_horn/46918-5-0-2.wav, 150 left
# sounds/car_horn/118279-8-0-2.wav, 149 left
# sounds/car_horn/108041-9-0-2.wav, 148 left
# sounds/car_horn/180937-7-3-20.wav, 147 left
# sounds/car_horn/166268-3-0-0.wav, 146 left
# sounds/car_horn/105415-2-0-1.wav, 145 left
# sounds/car_horn/59277-0-0-0.wav, 144 left
# sounds/car_horn/174290-6-1-0.wav, 143 left
# sounds/car_horn/59277-0-0-1.wav, 142 left
# sounds/car_horn/46669-4-0-35.wav, 141 left
# sounds/car_horn/132016-9-0-0.wav, 140 left
# sounds/car_horn/138031-2-0-7.wav, 139 left
# sounds/car_horn/180937-7-3-21.wav, 138 left
# sounds/car_horn/118279-8-0-3.wav, 137 left
# sounds/car_horn/180937-7-4-14.wav, 136 left
# sounds/car_horn/155202-9-0-38.wav, 135 left
# sounds/car_horn/143651-2-0-22.wav, 134 left
# sounds/car_horn/57584-4-0-3.wav, 133 left
# sounds/car_horn/69304-9-0-6.wav, 132 left
# sounds/car_horn/125791-3-0-12.wav, 131 left
# sounds/car_horn/150341-3-1-0.wav, 130 left
# sounds/car_horn/157867-8-0-27.wav, 129 left
# sounds/car_horn/55020-4-0-1.wav, 128 left
# sounds/car_horn/176787-5-0-2.wav, 127 left
# sounds/car_horn/146186-5-0-6.wav, 126 left
# sounds/car_horn/176714-2-0-26.wav, 125 left
# sounds/car_horn/57320-0-0-13.wav, 124 left
# sounds/car_horn/147764-4-0-0.wav, 123 left
# sounds/car_horn/164312-3-1-0.wav, 122 left
# sounds/car_horn/196087-2-0-0.wav, 121 left
# sounds/car_horn/97317-2-0-34.wav, 120 left
# sounds/car_horn/46656-6-1-0.wav, 119 left
# sounds/car_horn/134717-0-0-15.wav, 118 left
# sounds/car_horn/146186-5-0-2.wav, 117 left
# sounds/car_horn/135776-2-0-85.wav, 116 left
# sounds/car_horn/102842-3-1-6.wav, 115 left
# sounds/car_horn/180937-7-2-9.wav, 114 left
# sounds/car_horn/22962-4-0-0.wav, 113 left
# sounds/car_horn/50901-0-0-0.wav, 112 left
# sounds/car_horn/155202-9-0-126.wav, 111 left
# sounds/car_horn/55020-4-0-5.wav, 110 left
# sounds/car_horn/157867-8-0-23.wav, 109 left
# sounds/car_horn/151977-0-0-10.wav, 108 left
# sounds/car_horn/176787-5-0-6.wav, 107 left
# sounds/car_horn/57584-4-0-7.wav, 106 left
# sounds/car_horn/139951-9-0-29.wav, 105 left
# sounds/car_horn/46656-6-5-0.wav, 104 left
# sounds/car_horn/176638-1-0-0.wav, 103 left
# sounds/car_horn/180937-7-3-31.wav, 102 left
# sounds/car_horn/118279-8-0-7.wav, 101 left
# sounds/car_horn/108041-9-0-7.wav, 100 left
# sounds/car_horn/147764-4-4-0.wav, 99 left
# sounds/car_horn/193698-2-0-140.wav, 98 left
# sounds/car_horn/180937-7-3-19.wav, 97 left
# sounds/car_horn/180937-7-4-10.wav, 96 left
# sounds/car_horn/46669-4-0-31.wav, 95 left
# sounds/car_horn/165067-2-0-35.wav, 94 left
# sounds/car_horn/118279-8-0-12.wav, 93 left
# sounds/car_horn/105415-2-0-4.wav, 92 left
# sounds/car_horn/59277-0-0-5.wav, 91 left
# sounds/car_horn/59277-0-0-4.wav, 90 left
# sounds/car_horn/31323-3-0-1.wav, 89 left
# sounds/car_horn/161702-9-0-45.wav, 88 left
# sounds/car_horn/118279-8-0-13.wav, 87 left
# sounds/car_horn/191431-9-0-26.wav, 86 left
# sounds/car_horn/46669-4-0-24.wav, 85 left
# sounds/car_horn/194732-9-0-163.wav, 84 left
# sounds/car_horn/46669-4-0-30.wav, 83 left
# sounds/car_horn/180937-7-3-18.wav, 82 left
# sounds/car_horn/180937-7-4-11.wav, 81 left
# sounds/car_horn/180937-7-3-24.wav, 80 left
# sounds/car_horn/138031-2-0-2.wav, 79 left
# sounds/car_horn/108041-9-0-6.wav, 78 left
# sounds/car_horn/147764-4-4-1.wav, 77 left
# sounds/car_horn/118279-8-0-6.wav, 76 left
# sounds/car_horn/180937-7-3-30.wav, 75 left
# sounds/car_horn/101415-3-0-8.wav, 74 left
# sounds/car_horn/177621-0-0-0.wav, 73 left
# sounds/car_horn/57584-4-0-6.wav, 72 left
# sounds/car_horn/155202-9-0-6.wav, 71 left
# sounds/car_horn/151977-0-0-11.wav, 70 left
# sounds/car_horn/176787-5-0-7.wav, 69 left
# sounds/car_horn/157867-8-0-22.wav, 68 left
# sounds/car_horn/55020-4-0-4.wav, 67 left
# sounds/car_horn/22962-4-0-1.wav, 66 left
# sounds/car_horn/177621-0-0-27.wav, 65 left
# sounds/car_horn/180937-7-2-8.wav, 64 left
# sounds/car_horn/134717-0-0-28.wav, 63 left
# sounds/car_horn/135776-2-0-90.wav, 62 left
# sounds/car_horn/176714-2-0-23.wav, 61 left
# sounds/car_horn/146186-5-0-3.wav, 60 left
# sounds/car_horn/134717-0-0-14.wav, 59 left
# sounds/car_horn/138031-2-0-28.wav, 58 left
# sounds/car_horn/97317-2-0-25.wav, 57 left
# sounds/car_horn/134717-0-0-16.wav, 56 left
# sounds/car_horn/146186-5-0-1.wav, 55 left
# sounds/car_horn/102842-3-1-5.wav, 54 left
# sounds/car_horn/177621-0-0-31.wav, 53 left
# sounds/car_horn/157867-8-0-20.wav, 52 left
# sounds/car_horn/55020-4-0-6.wav, 51 left
# sounds/car_horn/76093-6-1-0.wav, 50 left
# sounds/car_horn/176787-5-0-5.wav, 49 left
# sounds/car_horn/151977-0-0-13.wav, 48 left
# sounds/car_horn/57584-4-0-4.wav, 47 left
# sounds/car_horn/125791-3-0-15.wav, 46 left
# sounds/car_horn/113205-5-1-8.wav, 45 left
# sounds/car_horn/177621-0-0-2.wav, 44 left
# sounds/car_horn/108041-9-0-4.wav, 43 left
# sounds/car_horn/180937-7-3-26.wav, 42 left
# sounds/car_horn/180937-7-3-32.wav, 41 left
# sounds/car_horn/118279-8-0-4.wav, 40 left
# sounds/car_horn/180937-7-4-13.wav, 39 left
# sounds/car_horn/46669-4-0-26.wav, 38 left
# sounds/car_horn/194732-9-0-175.wav, 37 left
# sounds/car_horn/46669-4-0-32.wav, 36 left
# sounds/car_horn/156194-1-0-0.wav, 35 left
# sounds/car_horn/191431-9-0-30.wav, 34 left
# sounds/car_horn/7383-3-1-0.wav, 33 left
# sounds/car_horn/118279-8-0-11.wav, 32 left
# sounds/car_horn/59277-0-0-6.wav, 31 left
# sounds/car_horn/132016-9-0-20.wav, 30 left
# sounds/car_horn/87275-1-5-0.wav, 29 left
# sounds/car_horn/105415-2-0-6.wav, 28 left
# sounds/car_horn/97317-2-0-5.wav, 27 left
# sounds/car_horn/59277-0-0-7.wav, 26 left
# sounds/car_horn/31323-3-0-2.wav, 25 left
# sounds/car_horn/118279-8-0-10.wav, 24 left
# sounds/car_horn/147764-4-6-0.wav, 23 left
# sounds/car_horn/132016-9-0-6.wav, 22 left
# sounds/car_horn/46669-4-0-33.wav, 21 left
# sounds/car_horn/180937-7-4-12.wav, 20 left
# sounds/car_horn/118279-8-0-5.wav, 19 left
# sounds/car_horn/180937-7-3-33.wav, 18 left
# sounds/car_horn/147764-4-4-2.wav, 17 left
# sounds/car_horn/180937-7-3-27.wav, 16 left
# sounds/car_horn/108041-9-0-5.wav, 15 left
# sounds/car_horn/139951-9-0-17.wav, 14 left
# sounds/car_horn/113205-5-1-9.wav, 13 left
# sounds/car_horn/69304-9-0-0.wav, 12 left
# sounds/car_horn/57584-4-0-5.wav, 11 left
# sounds/car_horn/176787-5-0-4.wav, 10 left
# sounds/car_horn/151977-0-0-12.wav, 9 left
# sounds/car_horn/55020-4-0-7.wav, 8 left
# sounds/car_horn/157867-8-0-21.wav, 7 left
# sounds/car_horn/155202-9-0-124.wav, 6 left
# sounds/car_horn/22962-4-0-2.wav, 5 left
# sounds/car_horn/89212-3-0-0.wav, 4 left
# sounds/car_horn/57320-0-0-15.wav, 3 left
# sounds/car_horn/146186-5-0-0.wav, 2 left
# sounds/car_horn/135776-2-0-50.wav, 1 left

# %%
labels = one_hot_encode(labels)

# %%
train_test_split = np.random.rand(len(features)) < 0.70
train_x = features[train_test_split]
train_y = labels[train_test_split]
test_x = features[~train_test_split]
test_y = labels[~train_test_split]

# %%
training_epochs = 5000
n_dim = features.shape[1]
n_classes = 10
n_hidden_units_one = 280 
n_hidden_units_two = 300
sd = 1 / np.sqrt(n_dim)
learning_rate = 0.01

# %%
X = tf.placeholder(tf.float32,[None,n_dim])
Y = tf.placeholder(tf.float32,[None,n_classes])

W_1 = tf.Variable(tf.random_normal([n_dim,n_hidden_units_one], mean = 0, stddev=sd))
b_1 = tf.Variable(tf.random_normal([n_hidden_units_one], mean = 0, stddev=sd))
h_1 = tf.nn.tanh(tf.matmul(X,W_1) + b_1)


W_2 = tf.Variable(tf.random_normal([n_hidden_units_one,n_hidden_units_two], mean = 0, stddev=sd))
b_2 = tf.Variable(tf.random_normal([n_hidden_units_two], mean = 0, stddev=sd))
h_2 = tf.nn.sigmoid(tf.matmul(h_1,W_2) + b_2)


W = tf.Variable(tf.random_normal([n_hidden_units_two,n_classes], mean = 0, stddev=sd))
b = tf.Variable(tf.random_normal([n_classes], mean = 0, stddev=sd))
y_ = tf.nn.softmax(tf.matmul(h_2,W) + b)

init = tf.global_variables_initializer()

# %%
cost_function = tf.reduce_mean(-tf.reduce_sum(Y * tf.log(y_), reduction_indices=[1])) 
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost_function)

correct_prediction = tf.equal(tf.argmax(y_,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
cost_history = np.empty(shape=[1],dtype=float)
y_true, y_pred = None, None
saver = tf.train.Saver()
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(training_epochs):
        if epoch % 500 == 0:
            print("epoch number == {}".format(epoch))
        _,cost = sess.run([optimizer,cost_function],feed_dict={X:train_x,Y:train_y})
        cost_history = np.append(cost_history,cost)
        
    print("Test accuracy: ",round(sess.run(accuracy, feed_dict={X: test_x, Y: test_y}),3))
    
    y_pred = sess.run(tf.argmax(y_,1),feed_dict={X: test_x})
    y_true = sess.run(tf.argmax(test_y,1))
    saver.save(sess, "/tmp/model.ckpt")
# Out:
# epoch number == 0
# epoch number == 500
# epoch number == 1000
# epoch number == 1500
# epoch number == 2000
# epoch number == 2500
# epoch number == 3000
# epoch number == 3500
# epoch number == 4000
# epoch number == 4500
# Test accuracy:  0.914

# %%
features = np.empty(0)
ext_features = np.hstack(extract_feature('sounds/car_horn/7061-6-0-0.wav'))
mytest_x = np.array(np.vstack([features,ext_features]))

with tf.Session() as sess:
    # Restore variables from disk.
    saver.restore(sess, "/tmp/model.ckpt")
    y_pred = sess.run(tf.argmax(y_,1), feed_dict={X: mytest_x})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-84d000c08899> in <module>
#       2 mfccs, chroma, mel, contrast,tonnetz = extract_feature('sounds/car_horn/7061-6-0-0.wav')
#       3 ext_features = np.hstack([mfccs,chroma,mel,contrast,tonnetz])
# ----> 4 mytest_x = np.array(np.vstack([features,ext_features]))
#       5
#       6 with tf.Session() as sess:
#
# ~/PycharmProjects/junction_outotec_ML/venv/lib/python3.6/site-packages/numpy/core/shape_base.py in vstack(tup)
#     232
#     233     """
# --> 234     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     235
#     236 def hstack(tup):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
y_pred
# Out:
# array([6])

# %%
features.shape[1]
# Out:
# 193
